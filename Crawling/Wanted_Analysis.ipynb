# %%
import json

import pandas as pd

from Crawling.Data_Analysis import *
from Crawling.Data_Analysis import mergeDataFrame

FILE_PATH = '../../Data_Files/Wanted_Analysis_20250604.txt'

# %%
detail_df = pd.read_json('../Data_Files/wanted_detail_improve_20250604.json')
detail_df = detail_df.T
detail_df
# Out:
#                                제목  \
# 283170                프로모션 기획 마케터
# 282132                    콘텐츠 에디터
# 282809                프로덕트 디자이너PD
# 278301          UIUX 디자이너신사업 프로덕트
# 279483         Frontend Developer
# ...                           ...
# 125154                   통합인허가 임원
# 124655                   통합인허가 팀장
# 76159   친환경 올인원 에어케어시스템 PCB 및 펌웨어
# 87790         PCB약품 개발, 제조업, 화학약품
# 80732                   CC++개발자3년
#
#                                                     회사 소개  \
# 283170  컬리 온사이트 마케팅 조직은 고객이 컬리에서 즐거운 장보기 경험을 하도록 돕고 그에...
# 282132  구분  신입경력계약기간 12개월조직소개콘텐츠기획팀은 크리에이티브 부문 콘텐츠크리에이...
# 282809  모든 사람이 편안하고 안전하게 이동할 수 있는 것타다가 모빌리티 시장의 이용자들에게...
# 278301  All Live Better,No1 헬스뷰티 스토어 올리브영은 20년 이상 축적된 ...
# 279483  꼭 확인해 주세요이력서 및 제출 서류에 허위 사실이 발견되거나 근무 이력 중 징계사...
# ...                                                   ...
# 125154                             엔코아네트웍스 통합인허가 임원 채용합니다
# 124655                             엔코아네트웍스 통합인허가 팀장 채용합니다
# 76159   안녕하세요 엔트 입니다당사는 탄소저감 공조시스템 개발을 통해 ESG 기업으로 성장하...
# 87790   NR지엔씨는 PCB 반도체 , 인쇄회로기판, 디스플레이 관련 약품 개발을 통해기술가...
# 80732   당사는 Xray 제조로서 코스닥 상장, 매출액 650억  인원 240명 글로벌 기업...
#
#                                                     주요 업무  \
# 283170  [사업 목표 달성을 위한 온사이트 프로모션 전략 수립 및 실행, , 1 연분기월 별...
# 282132  [콘텐츠기획팀은 단순히 글을 잘 쓰는 사람을 찾지 않습니다, 사용자가 무엇을 클릭하...
# 282809  [VCNC의 프로덕트 디자이너PD는 제품 기획개발 과정에서 핵심적인 역할을 담당하며...
# 278301  [올리브영 신사업 디플롯 프로덕트 웹APP 디자인,  UI디자인, UX설계 및 디자...
# 279483  [지금까진 이런 일을 했어요, 누구나 쉽게 원하는 결제 경험을 만들 수 있도록 치열...
# ...                                                   ...
# 125154  [통합인허가, 매채법 인허가, 엔지니어링 등 업무 수행,  전형절차  서류전형  1...
# 124655  [통합인허가, 메체법 인허가, 엔지니어링 등 업무 수행,  전형 절차  서류전형  ...
# 76159   [전자제품, 공조기 PCB 개발 및 외주업체 관리,  전자제품, 공조기 펌웨어 개발...
# 87790   [반도체, 인쇄회로기판, 디스플레이 관련 약품 개발,  신규약품 개발 및 분석,  ...
# 80732                     [SW 영상기기 개발,  SW 영상 뷰어,  SW 3D]
#
#                                                     자격 요건  \
# 283170  [경험,  최소 1년 이상의 유관 경험 또는 그에 준하는 역량을 보유하신 분,  경...
# 282132  [콘텐츠 운영의 흐름을 이해하고, 반복적인 업무에도 책임감 있게 임할 수 있는 분,...
# 282809  [최소 3년 이상의 프로덕트 디자이너 경력이 있는 분,  심미적이고 깔끔한 GUI를...
# 278301  [포트폴리오 필수 제출 바랍니다,  포트폴리오 파일 혹은 포트폴리오 사이트 URL과...
# 279483  [이런 분과 함께하고 싶어요, 개발자 경험에 대해 높은 가치를 두고 있는 분, 자동...
# ...                                                   ...
# 125154  [통합인허가 수행실적 2건이상  실무PM수행석유화학, 비철, 철강,  공정 해석분석...
# 124655  [통합인허가 수행실적 2건이상  실무PM수행석유화학, 비철, 철강,  공정 해석분석...
# 76159   [관련경험 5년 이상,  해외여행에 결격사유가 없는 분,  전기, 자동제어 개발업무...
# 87790                                      [화학관련학과 박사 졸업]
# 80732   [C++ 개발 가능자,  C++  QT 개발가능자,  OpenGLVTK 개발가능자,...
#
#                                                     우대 사항  \
# 283170  [Amplitude 활용이 가능하신 분,  서비스 마케팅, 사업 전략까지 확장 가능...
# 282132  [식품, 음식, 라이프스타일 관련 콘텐츠나 트렌드에 관심이 많은 분,  온라인 커머...
# 282809  [모빌리티 업계나 스타트업 산업에 대한 높은 이해도를 가지고 계신 분,  디자인 시...
# 278301  [SkillExperience,  이커머스 플랫폼 프로젝트 경험,  Agile 업무...
# 279483  [이런 경험이 있다면 이력서에 꼭 작성해 주세요, TypeScript, Flow를 ...
# ...                                                   ...
# 125154  [매체법 인허가 경력우대,  연령  제한없음3040대 우대,  입사시기  9월즉시 ...
# 124655  [매체법 인허가 경력우대,  연령  제한없음3040대 우대,  입사시기  9월즉시 ...
# 76159                            [인버터 압축기 경험,  에어컨 개발 경험]
# 87790   [개별 성과에 따른 인센티브 지급,  개인 차량 제공 차량 관련 모든 유지비용 지급...
# 80732   [PACS 개발경험자,  Agile Process,  XP, Scrum, Pari,...
#
#                                                        복지  \
# 283170  [모두가 집중하고 성장할 수 있도록, 최적의 근무 환경을 제공해요,  ,  리프레시...
# 282132  [우아한혜택 미리보기,  일한 만큼 드립니다 매월 소정근로시간 초과 시 분 단위로 ...
# 282809  [# 몰입을 위한 모든 것을 지원하는 타다 BOOST PACK , ,  Flexib...
# 278301  [CJ그룹 계열사 인프라 40 할인,  카페테리아 포인트현금성 복지 포인트혜택 개인...
# 279483  [이렇게 일해요,  자율과 책임의 문화 토스는 Manager가 아닌 Maker들로 ...
# ...                                                   ...
# 125154  [명절 상여금하계휴가지원비연말 성과금 지급,  직급수당직무수당자격수당잔여연차수당OT...
# 124655  [명절 상여금하계휴가지원비연말 성과금 지급,  직급수당직무수당자격수당잔여연차수당OT...
# 76159   [중식제공,  카페테리아,  4대보험,  연차휴가,  주 5일근무,  경조사 지원,...
# 87790   [연봉 외 개별 인센티브 지급,  식사제공 식사 or 식대 지급,  통신비 지원, ...
# 80732   [2년에 1번 대명리조트 콘도호텔 이용료 전액 지급,  듀얼 모니터 지급,  통근버...
#
#                                                      채용절차  \
# 283170  [합류 여정, 지원서 제출 직무 적합성 인터뷰  직무적합성검사 및 종합 인터뷰  최...
# 282132                                                 []
# 282809  [채용 Process,  서류 전형  직무 인터뷰  컬쳐핏 인터뷰  연봉 및 처우 ...
# 278301  [전형 안내, , 서류전형  1차면접  온라인 인성검사  2차면접  Referenc...
# 279483  [토스페이먼츠로의 합류 여정, 서류접수  사전 과제  직무 인터뷰  문화적합성 인터...
# ...                                                   ...
# 125154                                                 []
# 124655                                                 []
# 76159                                                  []
# 87790                                                  []
# 80732                                                  []
#
#                                                        장점            회사명 근무지  \
# 283170  [의료비지원, 휴가비, 유급휴가, 커피스낵바, 1,00110,000명, 설립10년이...             컬리  서울
# 282132  [복지포인트, 보너스, 단체보험, 어린이돌봄, 장비지원, 커피스낵바, 대출지원, 연...    우아한형제들배달의민족  서울
# 282809  [건강검진지원, 커피스낵바, 자기계발지원, 식대지원, 연봉상위610, 설립10년이상...         타다VCNC  서울
# 278301  [휴가비, 의료비지원, 건강검진지원, 편의시설, 자기계발지원, 수평적조직, 설립49...  씨제이올리브영CJ올리브영  서울
# 279483  [단체보험, 편의시설, 보너스, 커피스낵바, 설립49년, 유급휴가, 3011,000...         토스페이먼츠  서울
# ...                                                   ...            ...  ..
# 125154  [식대지원, 커피스낵바, 보너스, 50명이하, 인원 급성장, 설립10년이상, 연봉 ...        엔코아네트웍스  울산
# 124655  [식대지원, 커피스낵바, 보너스, 50명이하, 인원 급성장, 설립10년이상, 연봉 ...        엔코아네트웍스  울산
# 76159              [편의시설, 식대지원, 50명이하, 설립10년이상, 연봉상위1120]             엔트  경기
# 87790                           [식대지원, 보너스, 설립10년이상, 통신비]          엔알지엔씨  경기
# 80732   [보너스, 연봉상위1120, 3011,000명, 인원 급성장, 설립10년이상, 자기...           제노레이  경기
#
#          지역       직군                                 직무 기술 스택 요구 최소 경력  \
# 283170  강남구    마케팅광고             [마케터, 디지털 마케터, 모바일마케팅]    []        3
# 282132  송파구    마케팅광고                   [카피라이터, 콘텐츠 마케터]    []        0
# 282809  성동구      디자인   [모바일 디자이너, UI,GUI 디자이너, UX 디자이너]    []        3
# 278301  용산구      디자인                          [UX 디자이너]    []        4
# 279483  강남구       개발                        [프론트엔드 개발자]    []        0
# ...     ...      ...                                ...   ...      ...
# 125154   남구  엔지니어링설계                 [환경 엔지니어, 환경 안전기사]    []        5
# 124655   남구  엔지니어링설계                 [환경 엔지니어, 환경 안전기사]    []        5
# 76159   부천시       개발  [임베디드 개발자, 하드웨어 엔지니어, 소프트웨어 엔지니어]    []        5
# 87790   수원시       개발                             [기술지원]    []        0
# 80732   성남시       개발   [파이썬 개발자, C,C++ 개발자, 소프트웨어 엔지니어]    []        3
#
#        요구 최대 경력 신입 지원 가능 여부       마감일
# 283170       10       False     상시 공고
# 282132      100        True     상시 공고
# 282809        7       False     상시 공고
# 278301       11       False     상시 공고
# 279483      100        True  20250630
# ...         ...         ...       ...
# 125154       15       False     상시 공고
# 124655       15       False     상시 공고
# 76159        10       False     상시 공고
# 87790         1        True     상시 공고
# 80732        10       False     상시 공고
#
# [8707 rows x 18 columns]

# %% [markdown]
# # 직군별 개수부터 구하기

# %%
category_main = detail_df['직군'].explode()
category_main_count = category_main.value_counts().to_dict()
category_main_count = {
    '직군별 개수': category_main_count
}
original_json = getOriginalJson(FILE_PATH)
merge = mergeJsonDicts(original_json, category_main_count)
saveData(merge, FILE_PATH)
# Out:
# 새로운 JSON 파일을 생성했습니다.

# %%
category_main.value_counts()
# Out:
# 직군
# 개발          2546
# 경영비즈니스      1581
# 마케팅광고       1325
# 영업           695
# 디자인          690
# 고객서비스리테일     511
# 미디어          224
# 엔지니어링설계      201
# HR           153
# 금융           120
# 제조생산         116
# 정보보호         114
# 게임 제작        101
# 물류무역          96
# 교육            71
# 의료제약바이오       59
# 법률법집행기관       46
# 식음료           29
# 건설시설          23
# 공공복지           6
# Name: count, dtype: int64

# %% [markdown]
# # 직군별 직무 개수

# %%
category_main_sub = mergeDataFrame(detail_df['직무'].explode(),
                                   detail_df['직군'].explode())
original_json = getOriginalJson(FILE_PATH)
category_main_sub_count = category_main_sub.groupby('직군').value_counts().unstack(fill_value=0).to_dict()
category_main_sub_count = {
    '직군별 직무 개수': category_main_sub_count
}
merge = mergeJsonDicts(original_json, category_main_sub_count)
saveData(merge, FILE_PATH)
# Out:
# 기존 파일에 JSON을 덮어쓰기 성공했습니다.

# %% [markdown]
# # 직군별 기술스택의 개수 Top x

# %%
import pandas as pd


def top3_stack_per_job(detail_df: pd.DataFrame, tech_col: str = "기술 스택",
                       job_col: str = "직군", top_n: int = 3) -> dict:
    """
    직군별 상위 N개 기술 스택 + 개수를 JSON-용 딕셔너리로 반환
    --------------------------------------------------------
    반환 예:
    {
      "직군별 기술 스택 TOP3": {
        "백엔드":     {"Python": 128, "Java": 97,  "Spring": 91},
        "프론트엔드": {"React": 110, "JavaScript": 88, "TypeScript": 49},
        ...
      }
    }
    """

    # 1) 기술 스택 리스트를 행으로 펼치기
    df = detail_df[[job_col, tech_col]].explode(tech_col, ignore_index=True)

    # 2) 문자열화 + 공백 제거
    df[tech_col] = (
        df[tech_col]
        .fillna("")  # NaN → 빈문자
        .astype(str)
        .str.strip()
    )

    # 3) ***빈 문자열, 'nan', 직군 이름 자체 제거***
    mask_valid = (
            (df[tech_col] != "") &
            (df[tech_col].str.lower() != "nan") &
            (df[tech_col] != df[job_col])  # '백엔드'가 기술 스택에 섞이는 경우 방지
    )
    df = df[mask_valid]

    # 4) (직군, 기술) 빈도
    counts = (
        df.groupby([job_col, tech_col])
        .size()
        .rename("cnt")  # MultiIndex Series: (직군, 기술) → cnt
    )

    # 5) 직군별 상위 N 추출
    result = {}
    for job, sub in counts.groupby(level=0):
        top = (
            sub.sort_values(ascending=False)
            .head(top_n)
            .droplevel(0)  # 인덱스에서 직군 부분 제거 → 기술만 남김
        )
        result[job] = {tech: int(cnt) for tech, cnt in top.items()}

    return {f"직군별 기술 스택 TOP{top_n}": result}


# ── 사용 예 ────────────────────────────────────────────
top3_json = top3_stack_per_job(detail_df, top_n=5)

original = getOriginalJson(FILE_PATH)
merged = mergeJsonDicts(original, top3_json)
saveData(merged, FILE_PATH)
# Out:
# 기존 파일에 JSON을 덮어쓰기 성공했습니다.

# %% [markdown]
# # 직군별 신입 지원 가능 여부

# %%
# 1) (직군, 신입 여부)별 갯수 집계 → DataFrame
newbie_df = (
    detail_df.groupby(['직군', '신입 지원 가능 여부'])
             .size()                  # MultiIndex Series
             .unstack(fill_value=0)   # 칼럼: False / True
)

newbie_true = newbie_df.get(True, pd.Series(dtype=int))

# 3) Series → {직군: 개수} 딕셔너리
category_newbie_count = {
    '직군별 신입 지원 가능 여부': newbie_true.astype(int).to_dict()
}

# 결과 예시
# {
#   '직군별 신입 지원 가능 여부': {
#       '백엔드': 120,
#       '프론트엔드': 98,
#       '데이터': 45,
#       ...
#   }
# }
original_json = getOriginalJson(FILE_PATH)
merge = mergeJsonDicts(original_json, category_newbie_count)
saveData(merge, FILE_PATH)
# Out:
# 기존 파일에 JSON을 덮어쓰기 성공했습니다.

# %%
with open('../../Data_Files/Wanted_Analysis_20250604.txt', 'r', encoding='utf-8') as f:
    data = json.load(f)

with open('../Data_Files/Wanted_Analysis_20250604.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
data
# Out:
# {'직군별 개수': {'개발': 2546,
#   '경영비즈니스': 1581,
#   '마케팅광고': 1325,
#   '영업': 695,
#   '디자인': 690,
#   '고객서비스리테일': 511,
#   '미디어': 224,
#   '엔지니어링설계': 201,
#   'HR': 153,
#   '금융': 120,
#   '제조생산': 116,
#   '정보보호': 114,
#   '게임 제작': 101,
#   '물류무역': 96,
#   '교육': 71,
#   '의료제약바이오': 59,
#   '법률법집행기관': 46,
#   '식음료': 29,
#   '건설시설': 23,
#   '공공복지': 6},
#  '직군별 직무 개수': {'2D 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 26,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '3D 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 39,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'AS 기술자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 3,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'ATL 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 6,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'BI 엔지니어': {'HR': 0,
#    '개발': 4,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'BIBX 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 101,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'BTL 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 20,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'C,C++ 개발자': {'HR': 0,
#    '개발': 295,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 2,
#    '제조생산': 0},
#   'CAD3D 설계자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 38,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CEO,Chief Executive Officer': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 2,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CFO,Chief Financial Officer': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 11,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CIO,Chief Information Officer': {'HR': 0,
#    '개발': 1,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CISOCPO': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 4,
#    '제조생산': 0},
#   'CMO,Chief Marketing Officer': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 6,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'COO,Chief Operation Officer': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 7,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CRM 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 23,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CRM 전문가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 20,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CS 매니저': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 204,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CS 어드바이저': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 90,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CSO,Chief Strategy Officer': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 10,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'CTO,Chief Technology Officer': {'HR': 0,
#    '개발': 13,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'DBA': {'HR': 0,
#    '개발': 30,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'DevOps  시스템 관리자': {'HR': 0,
#    '개발': 186,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 2,
#    '제조생산': 0},
#   'ERP전문가': {'HR': 0,
#    '개발': 23,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'HR 컨설턴트': {'HR': 10,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'HRBP': {'HR': 17,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'HRD': {'HR': 11,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'IR': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 19,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'MD': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 202,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'NET 개발자': {'HR': 0,
#    '개발': 22,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'Nodejs 개발자': {'HR': 0,
#    '개발': 116,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'PD': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 72,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'PHP 개발자': {'HR': 0,
#    '개발': 23,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'PMPO': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 412,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'PR 전문가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 55,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'QA 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 11,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'QA,테스트 엔지니어': {'HR': 0,
#    '개발': 84,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'QC 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 5,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'RF 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 4,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'RPA 엔지니어': {'HR': 0,
#    '개발': 2,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'Sports 전문가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 1,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'UI,GUI 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 179,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'UX 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 225,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'UX 리서처': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 11,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'VMD': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 15,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'VR 엔지니어': {'HR': 0,
#    '개발': 8,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   'iOS 개발자': {'HR': 0,
#    '개발': 75,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '가구 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 2,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '가맹점 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 9,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '간호사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 4,
#    '정보보호': 0,
#    '제조생산': 0},
#   '개발 매니저': {'HR': 0,
#    '개발': 112,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '개인정보 담당자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 12,
#    '제조생산': 0},
#   '건설 안전품질검사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 1,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '건축가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 1,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '건축시공감리': {'HR': 0,
#    '개발': 0,
#    '건설시설': 18,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '게임 그래픽 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 18,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '게임 기획자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 33,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '게임 서버 개발자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 13,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '게임 아티스트': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 13,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '게임 클라이언트 개발자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 35,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '게임운영자GM': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 7,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '견적 기술자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 3,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '경영 혁신가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 12,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '경영지원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 133,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '경찰관': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 2,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '경호원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 1,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '고객성공매니저': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 60,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '공간 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 29,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '공무원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 4,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '공연 기획자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 5,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '공인회계사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 2,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '공정 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 14},
#   '공정 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 5,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '관리인': {'HR': 0,
#    '개발': 0,
#    '건설시설': 1,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '광고 기획자AE': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 186,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '광고 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 68,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '교사': {'HR': 1,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '교재교육기획': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 56,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '교직원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 5,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '구매담당': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 31,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '구조공학 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 6,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '그래픽 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 152,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '그래픽스 엔지니어': {'HR': 0,
#    '개발': 18,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '그로스 해커': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 43,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '글로벌 마케팅': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 219,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '금융공학자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 7,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '급여담당': {'HR': 23,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '기계 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 60,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '기계설비설계': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 14},
#   '기술영업': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 161,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '기술지원': {'HR': 0,
#    '개발': 80,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 1,
#    '제조생산': 0},
#   '기업영업': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 229,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '내부영업': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 32,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '내부통제 담당자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 11,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '노무노사': {'HR': 16,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '데이터 분석가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 114,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '데이터 사이언티스트': {'HR': 0,
#    '개발': 102,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '데이터 엔지니어': {'HR': 0,
#    '개발': 192,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '도면 담당자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 1,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '도면 작성가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 3,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '디지털 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 308,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '라이센스 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 7,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '레스토랑 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 1,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '로봇자동화': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 51,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '루비온레일즈 개발자': {'HR': 0,
#    '개발': 2,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '리셉션': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 7,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '리스크 관리 전문가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 27,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '리크루터': {'HR': 41,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '리테일 MD': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 119,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 495,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '마케팅 디렉터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 35,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '마케팅 전략 기획자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 315,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '마켓 리서처': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 14,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '매장 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 27,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '매장점원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 7,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '머신러닝 엔지니어': {'HR': 0,
#    '개발': 299,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '메뉴개발': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 2,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '모바일 게임 개발자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 21,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '모바일 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 32,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '모바일마케팅': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 20,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '모의해킹취약점 진단': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 8,
#    '제조생산': 0},
#   '무역사무': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 14,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '물류 분석가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 18,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '물류담당': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 71,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '물리 치료사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 4,
#    '정보보호': 0,
#    '제조생산': 0},
#   '미디어 세일즈': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 34,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '미생물학자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 1,
#    '정보보호': 0,
#    '제조생산': 0},
#   '바이어관리상담개발': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 4,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '반도체디스플레이': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 3},
#   '방사선사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 1,
#    '정보보호': 0,
#    '제조생산': 0},
#   '배송담당': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 4,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '법무 자문위원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 10,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '법무관': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 1,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '법무담당': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 28,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '법무사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 2,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '변리사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 2,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '변호사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 14,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '병원 코디네이터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 1,
#    '정보보호': 0,
#    '제조생산': 0},
#   '보안 엔지니어': {'HR': 0,
#    '개발': 10,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 96,
#    '제조생산': 0},
#   '보안관제': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 14,
#    '제조생산': 0},
#   '보험 에이전트': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 4,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '부동산 자산 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 1,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '부동산 중개사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 2,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '브랜드 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 267,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '블록체인 플랫폼 엔지니어': {'HR': 0,
#    '개발': 49,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '비디오 제작': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 22,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '비서': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 15,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '비주얼머천다이저': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 2,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '빅데이터 엔지니어': {'HR': 0,
#    '개발': 89,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '사무보조': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 45,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '사업개발기획자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 572,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '사진작가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 6,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '산업 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 22,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '상품기획자BM': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 87,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '생명공학 연구원': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 21,
#    '정보보호': 0,
#    '제조생산': 0},
#   '생물의학자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 1,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '생산 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 43},
#   '생산공학 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 2,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '생산직 종사자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 6},
#   '서버 개발자': {'HR': 0,
#    '개발': 505,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 2,
#    '제조생산': 0},
#   '서비스 기획자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 393,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
# ...
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '콘텐츠 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 396,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '콘텐츠 에디터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 14,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '콘텐츠 크리에이터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 84,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '큐레이터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 1,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '크로스플랫폼 앱 개발자': {'HR': 0,
#    '개발': 57,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '키워드광고': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 14,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '통번역': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 20,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '투자은행가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 3,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '투자증권': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 21,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '트레이더': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 1,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '특허담당': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 6,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '파이썬 개발자': {'HR': 0,
#    '개발': 363,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 2,
#    '제조생산': 0},
#   '패브릭 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 6,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '패션 MD': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 54,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '패션 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 27,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '패키지 디자이너': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 56,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '퍼포먼스 마케터': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 291,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '평가보상': {'HR': 33,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '푸드스타일리스트': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 2,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '품질 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 54},
#   '프로덕트 매니저': {'HR': 0,
#    '개발': 53,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '프로젝트 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 3,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '프론트엔드 개발자': {'HR': 0,
#    '개발': 440,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '플랜트 관리자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 1,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '플랜트 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 2,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '플로리스트': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 1,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '피부관리사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 1,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '하드웨어 엔지니어': {'HR': 0,
#    '개발': 84,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '학원강사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 7,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '항공 운송': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 1,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '항공우주 공학자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 12,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '해양공학자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 2,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '해외 사업개발기획자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 130,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '해외영업': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 169,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '해운해양 운송': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 1,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '헤드헌터': {'HR': 8,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '헬스케어매니저': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 2,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '현장 소장': {'HR': 0,
#    '개발': 0,
#    '건설시설': 8,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '화물트럭 운전기사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 2,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '화학공학 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 3,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '화학자': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 1},
#   '환경 안전기사': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 3,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '환경 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 3,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '환경 전문가': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 2,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '회계경리': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 157,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '회계담당': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 51,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 0,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0},
#   '회전기계 엔지니어': {'HR': 0,
#    '개발': 0,
#    '건설시설': 0,
#    '게임 제작': 0,
#    '경영비즈니스': 0,
#    '고객서비스리테일': 0,
#    '공공복지': 0,
#    '교육': 0,
#    '금융': 0,
#    '디자인': 0,
#    '마케팅광고': 0,
#    '물류무역': 0,
#    '미디어': 0,
#    '법률법집행기관': 0,
#    '식음료': 0,
#    '엔지니어링설계': 2,
#    '영업': 0,
#    '의료제약바이오': 0,
#    '정보보호': 0,
#    '제조생산': 0}},
#  '직군별 기술 스택 TOP5': {'HR': {'보상': 5, '인사 관리': 5, '노무 관리': 3, '평가': 3, 'HRD': 3},
#   '개발': {'Python': 270,
#    'AWS': 219,
#    'Git': 142,
#    'Docker': 131,
#    'JavaScript': 129},
#   '건설시설': {'AutoCAD Architecture': 1,
#    'CAD': 1,
#    '컴퓨터 수리': 1,
#    '컴퓨터 능력': 1,
#    '컴퓨터 구조': 1},
#   '게임 제작': {'C++': 6,
#    'Unity3D': 5,
#    'C#': 4,
#    'JavaScript': 3,
#    'Unreal Engine': 3},
#   '경영비즈니스': {'Notion': 30, 'Slack': 27, 'Figma': 24, 'Excel': 21, 'SQL': 16},
#   '고객서비스리테일': {'Excel': 11, 'Notion': 10, 'Slack': 8, 'MS 오피스': 5, '고객 경험': 5},
#   '교육': {'Adobe Photoshop': 1, 'Excel': 1, 'Maya': 1, 'Notion': 1, 'Slack': 1},
#   '금융': {'Python': 2, 'AML': 1, 'AWS': 1, 'Data Analysis': 1, 'Excel': 1},
#   '디자인': {'Figma': 73,
#    'Adobe Photoshop': 62,
#    'Adobe Illustrator': 60,
#    'UI 디자인': 38,
#    '그래픽 디자인': 31},
#   '마케팅광고': {'Google Analytics': 32,
#    'Notion': 21,
#    '마케팅 전략': 21,
#    'Slack': 20,
#    '마케팅 분석': 18},
#   '물류무역': {'영업': 2, '3PL': 1, 'Excel': 1, 'Notion': 1, 'Slack': 1},
#   '미디어': {'Adobe Premiere': 11,
#    'After Effect': 7,
#    'Adobe Photoshop': 6,
#    'Slack': 3,
#    'Adobe Illustrator': 3},
#   '법률법집행기관': {'특허': 2, '특허 분석': 2, '특허 전략': 2, '법무': 1},
#   '식음료': {'Notion': 2,
#    'Slack': 2,
#    'Communication': 1,
#    'Excel': 1,
#    '스프레드 시트': 1},
#   '엔지니어링설계': {'Solidworks': 9, 'C++': 8, 'Git': 7, 'Python': 7, 'Verilog': 7},
#   '영업': {'영업 담당자': 9, 'Slack': 9, '영업 관리': 9, 'Notion': 8, '영업 운영': 8},
#   '의료제약바이오': {'PowerPoint': 2,
#    'Python': 2,
#    'Notion': 2,
#    '제약 산업': 1,
#    '임상 운영': 1},
#   '정보보호': {'Go': 3, 'Rust': 3, 'C++': 2, 'AWS': 1, 'ISO 27001': 1},
#   '제조생산': {'Slack': 2, 'Notion': 2, 'Excel': 1, '생산': 1, '커뮤니케이션 디자인': 1}},
#  '직군별 신입 지원 가능 여부': {'HR': 20,
#   '개발': 259,
#   '건설시설': 1,
#   '게임 제작': 15,
#   '경영비즈니스': 264,
#   '고객서비스리테일': 140,
#   '공공복지': 1,
#   '교육': 17,
#   '금융': 18,
#   '디자인': 111,
#   '마케팅광고': 228,
#   '물류무역': 27,
#   '미디어': 56,
#   '법률법집행기관': 10,
#   '식음료': 9,
#   '엔지니어링설계': 52,
#   '영업': 141,
#   '의료제약바이오': 12,
#   '정보보호': 5,
#   '제조생산': 17}}
